# %%
import requests
from bs4 import BeautifulSoup

url = 'https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EC%9D%B8%ED%84%B0%EB%84%B7_%EC%8B%A0%EC%A1%B0%EC%96%B4_%EB%AA%A9%EB%A1%9D'
r = requests.get(url)

print(r) # 응답 객체
r.text # HTML 텍스트
# Out:
# <Response [200]>
# ...

# %%
soup=BeautifulSoup(r.text, 'lxml')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <title>대한민국의 인터넷 신조어 목록 - 위키백과, 우리 모두의 백과사전</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"ko","wgMonthNames":["","1월","2월","3월","4월","5월","6월","7월","8월","9월","10월","11월","12월"],"wgRequestId":"9b07b076-6285-4c2a-a217-c86a3b805097","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"대한민국의_인터넷_신조어_목록","wgTitle":"대한민국의 인터넷 신조어 목록","wgCurRevisionId":33097761,"wgRevisionId":33097761,"wgArticleId":401519,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 - 영어 인용 (en)","깨진 링크를 가지고 있는 문서","독자 연구 의심 문서/2022년 7월","모든 독자 연구 의심 문서","독자 연구 의심 문서 - 전체","출처가 필요한 글","출처가 필요한 글/2021년 2월",
# ...

# %%
soup.find_all('b')
# Out:
# [<b><a href="/wiki/%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC:%EB%8F%85%EC%9E%90_%EC%97%B0%EA%B5%AC_%EA%B8%88%EC%A7%80" title="위키백과:독자 연구 금지">기여자 고유의 독자적인 연구</a> 또는 <a href="/wiki/%EC%9C%84%ED%82%A4%EB%B0%B1%EA%B3%BC:%ED%99%95%EC%9D%B8_%EA%B0%80%EB%8A%A5" title="위키백과:확인 가능">확인되지 않은 내용</a>이 담겨 있을 수 있습니다.</b>,
#  <b>대한민국의 인터넷 신조어</b>,
#  <b><a href="/wiki/%EA%B0%80%EC%A6%88%EC%95%84" title="가즈아">가즈아</a></b>,
#  <b><a href="/wiki/%EA%B5%AD%EB%BD%95" title="국뽕">국뽕</a></b>,
#  <b><a href="/wiki/%EC%88%98%EC%A0%80%EA%B3%84%EA%B8%89%EB%A1%A0" title="수저계급론">금수저</a></b>,
#  <b>급식체</b>,
#  <b>급식충</b>,
#  <b>뇌피셜</b>,
#  <b><a href="/wiki/%EB%89%B4%ED%8A%B8%EB%A1%9C" title="뉴트로">뉴트로</a></b>,
#  <b>딸바보</b>,
#  <b>똥꼬충</b>,
#  <b><a href="/wiki/%EA%BC%B0%EB%8C%80" title="꼰대">라떼는 말이야</a></b>,
#  <b>라떼드립</b>,
#  <b>레게노</b>,
#  <b>ㅁㄴㅇㄹ</b>,
#  <b>맘충</b>,
#  <b>몸짱</b>,
#  <b>-밍아웃</b>,
#  <b>벼락거지</b>,
#  <b>빵셔틀</b>,
#  <b>뽀짝</b>,
#  <b>섹시 도발</b>,
#  <b>샵쥐 (#G)</b>,
#  <b>시발비용</b>,
#  <b>아무 말 대잔치</b>,
# ...

# %%
len(soup.find_all('b'))
# Out:
# 210

# %%
for k in range(2,210):
    print(soup.find_all('b')[k].text)
# Out:
# 가즈아
# 국뽕
# 금수저
# 급식체
# 급식충
# 뇌피셜
# 뉴트로
# 딸바보
# 똥꼬충
# 라떼는 말이야
# 라떼드립
# 레게노
# ㅁㄴㅇㄹ
# 맘충
# 몸짱
# -밍아웃
# 벼락거지
# 빵셔틀
# 뽀짝
# 섹시 도발
# 샵쥐 (#G)
# 시발비용
# 아무 말 대잔치
# 외계어
# 월급루팡
# 역대급
# 의문의 1승
# 일진
# 어쩔티비
# 잼민이
# 지름신
# 지르다
# 뽐뿌
# 진지충
# 짐승남
# 짐승돌
# 짱
# 저쩔티비
# 창렬
# 혜자
# -충
# 치느님
# 캐-
# ㅋㅋ
# 크크루삥뽕
# 킹-
# 탕진잼
# 틀딱충
# 틀딱
# 품절남
# 품절녀
# 플렉스
# 핵-
# 혈중 마라 농도
# 홍대병
# 흙수저
# 가성비
# 가심비
# 강퇴
# -까
# 갑분싸
# 낄끼빠빠
# 갑툭튀
# 김치년
# 나나
# 남사친
# 내로남불
# 넘사벽
# 단짠
# 대깨-
# 대깨문, 대깨윤'
# 대깨근'
# 대깨트'
# 대깨옵'
# 듣보잡
# ㄹㅇㅋㅋ
# 만반잘부
# 먹튀
# 문찐
# 밀당
# 브금
# 사바사
# 성진국
# 셀카
# 솔까말
# 스펙
# 썸
# 악플
# 안물안궁
# 엄친아
# 엑박
# 여사친
# 열폭
# 용자
# 움짤
# 웃프다
# 이뭐병
# 이왜진
# 이생망
# 일코
# 알잘딱깔센
# 억까
# 오하운:
# ㅈㄱㄴ
# 제곧내
# ㅈㅅ
# 졌잘싸
# 존맛
# 존맛탱
# JMT
# 즐
# 지못미
# 치맥
# 카공족
# 케바케
# ㅋㅋ
# 텅장
# ㅍ
# 피싸개
# 한남
# 한남충
# 흠좀무
# UBD
# -각
# 개이득
# 개피
# 갱
# 광클
# 너프
# 디버프
# 다굴
# 득템
# 본캐
# 부캐
# 서로서로 도와요!(서서도)
# 캐리/하드캐리
# 테크트리/테크/트리
# 개드립
# 뇌절
# 덕후
# 덕
# 오덕후
# 오덕
# 덕질
# 레알
# 병맛
# 뷁
# 짤방
# 짤
# 킹왕짱
# 甲
# 갑
# 고구마
# 번개
# 사이다
# 완전
# 인증
# 1도
# 극대노
# 먹방
# 빵꾸똥꾸
# 좋은가봉가
# 케찹고백
# 누가 기침소리를 내었어
# 나베
# ...
